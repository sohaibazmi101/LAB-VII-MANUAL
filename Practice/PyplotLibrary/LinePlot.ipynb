# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6])
y = np.array([10, 26])
plt.plot(x, y)

# To plot a line from points a = (1, 9) and b = (3, 10)
# We need to pass as x_points = (1,3) and y_points = (9,10)

x_points = np.array([1,3])
y_points = np.array([9,10])
plt.plot(x_points, y_points)
# # # or
# plt.plot((1,3),(9,10))
# plt.show()

# What if we need to draw points on graph at any position?
# lets take two points a=(1,10) and b = (2,12)

x_points = (1,2)
y_points = (10,12)
plt.plot(x_points, y_points, 'o')

# What happens when we need to plot multiple lines 
# lets a=(1,2), b = (0, 0), c = (10,10), d=(10,19)
# we need to plot from a to b then b to c then to d from c

x_points_in_array = np.array([1,0,10,10])
y_points_in_array = np.array([2,0,10,19])
plt.plot(x_points_in_array, y_points_in_array)
plt.plot(x_points_in_array, y_points_in_array, linestyle = 'dotted')

s1 = np.array([1,2,3,4,5,7,6,4,6,16,23])
s2 = np.array([12,32,4,5,43,6,45,7,19,54,23])
x_p = np.array([19,10,20,11,14])
y_p = np.array([11,23,43,23,12])
plt.plot(x_p, y_p)
plt.title("Hello World")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
print(len(s1))
print(len(s2))
plt.scatter(s1, s2)
# plt.grid()
plt.show()
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()
# Out:
# 11
# 11
