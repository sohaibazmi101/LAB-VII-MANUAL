# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['A','B', 'C','D'])
y = np.array([10,12,13,9])
plt.bar(x,y)
plt.plot(x,y, color='orange')
plt.show()
x_ap = ['Apple', 'Banana', 'Orange','Guvava']
y_ap = [190, 320, 120, 300]
plt.bar(x_ap, y_ap, color='r', width=0.1)
plt.show()
plt.barh(x_ap, y_ap, color='r', height=0.1)
plt.show()

x_hist = np.random.normal(170, 10, 250)
# print(x_hist)
plt.hist(x_hist)
# plt.plot(x_hist, color='r')
plt.show()
num = np.random.normal(100, 10, 8)
plt.pie(num)
plt.show()
# Out:
# [ 98.76422112 123.37946204 114.52223253 111.69682523  88.60772861
#   97.36101449  93.64725682 111.24084969]
